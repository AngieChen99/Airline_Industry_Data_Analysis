# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_excel("C:\\Users\\TestUser\\Desktop\\employee_data_1.xlsx")
df.head(5)
# Out:
#     Airline Hue_Index  Year  Total_FTE_Equivalents  Average_Annual_Wages  \
# 0  American   Network  1995                83463.0          48609.240023
# 1  American   Network  1996                78902.0          49007.388913
# 2  American   Network  1997                80842.0          50991.068999
# 3  American   Network  1998                82470.0          52374.887838
# 4  American   Network  1999                90136.0          49537.720777
#
#    Average_Pension_Benefit   Total_Pilot_Employee   \
# 0              14218.024753                   9000
# 1              10310.562470                   8954
# 2               9209.482695                   8885
# 3               9641.930399                   8813
# 4               9843.103754                   9533
#
#    Average_Annual_Wages_PILOT  Average_Pension_PILOTS  Total_Flight_Attendant  \
# 0               112190.222222            29950.888889                   18013
# ...

# %%
# Exploratory Data
df.describe().T
df.info()
print(df.shape)

# drop missing values
df.dropna(axis=0,inplace=True)
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 370 entries, 0 to 415
# Data columns (total 24 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Airline                                     370 non-null    object
#  1   Hue_Index                                   370 non-null    object
#  2   Year                                        370 non-null    int64
#  3   Total_FTE_Equivalents                       370 non-null    float64
#  4   Average_Annual_Wages                        370 non-null    float64
#  5   Average_Pension_Benefit                     370 non-null    float64
#  6   Total_Pilot_Employee                        370 non-null    int64
#  7   Average_Annual_Wages_PILOT                  370 non-null    float64
#  8   Average_Pension_PILOTS                      370 non-null    float64
#  9   Total_Flight_Attendant                      370 non-null    int64
# ...

# %%
air = df.groupby('Year')['Average_Annual_Wages'].agg(air=sum).reset_index()
air = air.rename(columns={'Year':'ds','air':'y'})
plt.figure(figsize=(10,7))
plt.plot(air['ds'], air['y'])

# %%
df_emp = pd.read_excel("C:\\Users\\TestUser\\Desktop\\employee_wage.xlsx")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df_emp, hue="Hue_Index")

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('ticks')
# the size of A4 paper
fig.set_size_inches(11.7, 8.27)
sns.relplot( data=df_emp,kind="line", x="Year", y="Average_Annual_Wages",hue="Hue_Index")

# %%
df_A = pd.read_excel("C:\\Users\\TestUser\\Desktop\ASMdata.xlsx")

# %%
sns.lineplot(data=df, x="Year", y="ASM_employee",hue="Hue_Index")
plt.figure(figsize = (15,9))

# %%
df_ASM = pd.read_excel("C:\\Users\\TestUser\\Desktop\\EMPASM.xlsx")

# %%
df_ASM = pd.read_excel("C:\\Users\\TestUser\\Desktop\\EMPASM.xlsx")
df_ASM.head()
# Out:
#     Airline Hue_Index  Year  Average_Annual_Wages   Avg_Pension  ASM_employee
# 0  American   Network  1995          48609.240023  14218.024753      1.859228
# 1  American   Network  1996          49007.388913  10310.562470      1.936530
# 2  American   Network  1997          50991.068999   9209.482695      1.904002
# 3  American   Network  1998          52374.887838   9641.930399      1.883130
# 4  American   Network  1999          49537.720777   9843.103754      1.779956

# %%
df_ASM.groupby('Airline')['Avg_Pension'].sum().plot(kind = "pie",figsize=(18,17),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Avg_Pension'>
